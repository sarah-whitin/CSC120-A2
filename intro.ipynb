# %% [markdown]
# <a href="https://colab.research.google.com/github/sarah-whitin/CSC120-A2/blob/master/intro.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import torch
import numpy as np

# %% [markdown]
# # Tensors

# %% [markdown]
# **Tensors**
# *  A torch. Tensor is a multi-dimensional matrix containing elements of a single data type
# *   Similiar to Numpy Arrays, but full of fun things that make them work better in GPU's (vs regular CPUs)
# *   default data type of float32
# *   more suitable for deep learning than a numpy array

# %% [markdown]
# # Lists

# %%
my_list = [[1,2,3,4],[6,7,8,9,10]]
my_list

# %%
[]
